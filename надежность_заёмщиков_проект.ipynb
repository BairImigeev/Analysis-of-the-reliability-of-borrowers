# %% [markdown]
# # Исследование надёжности заёмщиков
#
# Заказчик — кредитный отдел банка. Разбор : влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# ## Признаки
#
#
# - children — количество детей в семье
# - days_employed — общий трудовой стаж в днях
# - dob_years — возраст клиента в годах
# - education — уровень образования клиента
# - education_id — идентификатор уровня образования
# - family_status — семейное положение
# - family_status_id — идентификатор семейного положения
# - gender — пол клиента
# - income_type — тип занятости
# - debt — имел ли задолженность по возврату кредитов
# - total_income — ежемесячный доход
# - purpose — цель получения кредита.

# %% [markdown]
# Предобработка данных:
# - Аномалии;
# - Корректировка типов данных;
# - Дубликаты;
# - Пропущенные значения.
#
# Проверка гипотез:
# - зависимость между наличием детей и возвратом кредита в срок;
# - зависимость между семейным положением и возвратом кредита в срок;
# - зависимость между уровнем дохода и возвратом кредита в срок;
# - Цели кредита и возврат кредита в срок;

# %% [markdown]
# Подготовка и предварительный осмотр

# %%
# %pip install pymorphy2

# %%
# %pip install pandas-profiling

# %%
# %pip uninstall markupsafe
# %pip install markupsafe==2.0.1

# %%
# Ваш код здесь
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import math 
import statistics
# pd.set_option('display.max_columns', None)
# pd.options.display.max_colwidth = 150
from pandas_profiling import ProfileReport

# profile = ProfileReport(df, title='Профиль_Пандас_Репорт')
import pandas_profiling as pp


import nltk # библиотека nltk
from nltk.tokenize import word_tokenize, sent_tokenize # готовые токенизаторы библиотеки nltk
from pymorphy2 import MorphAnalyzer

# импортируем стоп-слова из библиотеки nltk
from nltk.corpus import stopwords

# %%
df = pd.read_csv('data.csv',sep=',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %%
df.duplicated().sum()
# Out:
# 54

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21471 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21471 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21471 non-null  int64
#  3   education         21471 non-null  object
#  4   education_id      21471 non-null  int64
#  5   family_status     21471 non-null  object
#  6   family_status_id  21471 non-null  int64
#  7   gender            21471 non-null  object
#  8   income_type       21471 non-null  object
#  9   debt              21471 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21471 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.1+ MB

# %% [markdown]
# Переведём текст на русский язык приятный для глаз.

# %%
dict_to_rus = {
    'children': 'количество детей в семье',
    'days_employed':'общий трудовой стаж в днях',
    'dob_years': 'возраст клиента в годах',
    'education': 'уровень образования клиента',
    'education_id': 'идентификатор уровня образования',
    'family_status': 'семейное положение',
    'family_status_id': 'идентификатор семейного положения',
    'gender':'пол',
    'income_type':'тип занятости',
    'debt': 'имел ли задолженность по возврату кредитов',
    'total_income':'ежемесячный доход',
    'purpose':'цель получения кредита'
}

df.rename(columns = (dict_to_rus), inplace=True)

# %% [markdown]
# Cделаем функцию вывода уникальных значений и пропусков, чтобы обращаться к ней, если нам понадобиться

# %%
def out_df_uniq_propusk(df):
    for i in df:
        print('*'*125)
        print('\n')
        print('Столбец : ', i)
        print('уникальные значения : ', df[i].unique())
        print('\n')
        print('пропуски : ', df[i].isnull().sum())
        print('\n')
        print('Описательная статистика : ')
        print(df[i].describe())
        print('\n')
        print('Количество значений : ')
        print(df[i].value_counts())
        print('\n')

out_df_uniq_propusk(df)
# Out:
# *****************************************************************************************************************************
#
#
# Столбец :  количество детей в семье
# уникальные значения :  [ 1  0  3  2 -1  4 20  5]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21471.000000
# mean         0.539565
# std          1.382978
# min         -1.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         20.000000
# Name: количество детей в семье, dtype: float64
#
#
# Количество значений :
#  0     14107
#  1      4809
#  2      2052
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: количество детей в семье, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  общий трудовой стаж в днях
# уникальные значения :  [-8437.67302776 -4024.80375385 -5623.42261023 ... -2113.3468877
#  -3112.4817052  -1984.50758853]
#
#
# пропуски :  2120
#
#
# Описательная статистика :
# count     19351.000000
# mean      63046.497661
# std      140827.311974
# min      -18388.949901
# 25%       -2747.423625
# 50%       -1203.369529
# 75%        -291.095954
# max      401755.400475
# Name: общий трудовой стаж в днях, dtype: float64
#
#
# Количество значений :
# -8437.673028      1
# -3507.818775      1
#  354500.415854    1
# -769.717438       1
# -3963.590317      1
#                  ..
# -1099.957609      1
# -209.984794       1
#  398099.392433    1
# -1271.038880      1
# -1984.507589      1
# Name: общий трудовой стаж в днях, Length: 19351, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  возраст клиента в годах
# уникальные значения :  [42 36 33 32 53 27 43 50 35 41 40 65 54 56 26 48 24 21 57 67 28 63 62 47
#  34 68 25 31 30 20 49 37 45 61 64 44 52 46 23 38 39 51  0 59 29 60 55 58
#  71 22 73 66 69 19 72 70 74 75]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21471.000000
# mean        43.279074
# std         12.574291
# min          0.000000
# 25%         33.000000
# 50%         42.000000
# 75%         53.000000
# max         75.000000
# Name: возраст клиента в годах, dtype: float64
#
#
# Количество значений :
# 35    616
# 40    607
# 41    606
# 34    601
# 38    597
# 42    596
# 33    581
# 39    572
# 31    559
# 36    554
# 44    545
# 29    544
# 30    538
# 48    537
# 37    536
# 50    513
# 43    512
# 32    509
# 49    508
# 28    503
# 45    497
# 27    493
# 52    484
# 56    484
# 47    477
# 54    476
# 46    473
# 53    459
# 57    456
# 58    456
# 51    448
# 59    443
# 55    443
# 26    408
# 60    374
# 25    357
# 61    354
# 62    349
# 63    269
# 24    264
# 64    262
# 23    253
# 65    194
# 22    183
# 66    182
# 67    167
# 21    111
# 0     101
# 68     99
# 69     85
# 70     65
# 71     58
# 20     51
# 72     33
# 19     14
# 73      8
# 74      6
# 75      1
# Name: возраст клиента в годах, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  уровень образования клиента
# уникальные значения :  ['высшее' 'среднее' 'Среднее' 'СРЕДНЕЕ' 'ВЫСШЕЕ' 'неоконченное высшее'
#  'начальное' 'Высшее' 'НЕОКОНЧЕННОЕ ВЫСШЕЕ' 'Неоконченное высшее'
#  'НАЧАЛЬНОЕ' 'Начальное' 'Ученая степень' 'УЧЕНАЯ СТЕПЕНЬ'
#  'ученая степень']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count       21471
# unique         15
# top       среднее
# freq        13705
# Name: уровень образования клиента, dtype: object
#
#
# Количество значений :
# среднее                13705
# высшее                  4710
# СРЕДНЕЕ                  772
# Среднее                  711
# неоконченное высшее      668
# ВЫСШЕЕ                   273
# Высшее                   268
# начальное                250
# Неоконченное высшее       47
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       29
# НАЧАЛЬНОЕ                 17
# Начальное                 15
# ученая степень             4
# Ученая степень             1
# УЧЕНАЯ СТЕПЕНЬ             1
# Name: уровень образования клиента, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  идентификатор уровня образования
# уникальные значения :  [0 1 2 3 4]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21471.000000
# mean         0.817195
# std          0.548508
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          4.000000
# Name: идентификатор уровня образования, dtype: float64
#
#
# Количество значений :
# 1    15188
# 0     5251
# 2      744
# 3      282
# 4        6
# Name: идентификатор уровня образования, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  семейное положение
# уникальные значения :  ['женат / замужем' 'гражданский брак' 'вдовец / вдова' 'в разводе'
#  'Не женат / не замужем']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count               21471
# unique                  5
# top       женат / замужем
# freq                12344
# Name: семейное положение, dtype: object
#
#
# Количество значений :
# женат / замужем          12344
# гражданский брак          4163
# Не женат / не замужем     2810
# в разводе                 1195
# вдовец / вдова             959
# Name: семейное положение, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  идентификатор семейного положения
# уникальные значения :  [0 1 2 3 4]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21471.000000
# mean         0.973685
# std          1.421082
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          4.000000
# Name: идентификатор семейного положения, dtype: float64
#
#
# Количество значений :
# 0    12344
# 1     4163
# 4     2810
# 3     1195
# 2      959
# Name: идентификатор семейного положения, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  пол
# уникальные значения :  ['F' 'M' 'XNA']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count     21471
# unique        3
# top           F
# freq      14189
# Name: пол, dtype: object
#
#
# Количество значений :
# F      14189
# M       7281
# XNA        1
# Name: пол, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  тип занятости
# уникальные значения :  ['сотрудник' 'пенсионер' 'компаньон' 'госслужащий' 'безработный'
#  'предприниматель' 'студент' 'в декрете']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count         21471
# unique            8
# top       сотрудник
# freq          11091
# Name: тип занятости, dtype: object
#
#
# Количество значений :
# сотрудник          11091
# компаньон           5080
# пенсионер           3837
# госслужащий         1457
# безработный            2
# предприниматель        2
# студент                1
# в декрете              1
# Name: тип занятости, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  имел ли задолженность по возврату кредитов
# уникальные значения :  [0 1]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21471.000000
# mean         0.081086
# std          0.272974
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: имел ли задолженность по возврату кредитов, dtype: float64
#
#
# Количество значений :
# 0    19730
# 1     1741
# Name: имел ли задолженность по возврату кредитов, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  ежемесячный доход
# уникальные значения :  [253875.6394526  112080.01410244 145885.95229686 ...  89672.56115303
#  244093.05050043  82047.41889948]
#
#
# пропуски :  2120
#
#
# Описательная статистика :
# count    1.935100e+04
# mean     1.674223e+05
# std      1.029716e+05
# min      2.066726e+04
# 25%      1.030532e+05
# 50%      1.450179e+05
# 75%      2.034351e+05
# max      2.265604e+06
# Name: ежемесячный доход, dtype: float64
#
#
# Количество значений :
# 253875.639453    1
# 157691.851056    1
# 70113.902786     1
# 116196.518662    1
# 157205.834562    1
#                 ..
# 168880.592469    1
# 148042.721049    1
# 60039.334460     1
# 175979.762960    1
# 82047.418899     1
# Name: ежемесячный доход, Length: 19351, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  цель получения кредита
# уникальные значения :  ['покупка жилья' 'приобретение автомобиля' 'дополнительное образование'
#  'сыграть свадьбу' 'операции с жильем' 'образование'
#  'на проведение свадьбы' 'покупка жилья для семьи' 'покупка недвижимости'
#  'покупка коммерческой недвижимости' 'покупка жилой недвижимости'
#  'строительство собственной недвижимости' 'недвижимость'
#  'строительство недвижимости' 'на покупку подержанного автомобиля'
#  'на покупку своего автомобиля' 'операции с коммерческой недвижимостью'
#  'строительство жилой недвижимости' 'жилье'
#  'операции со своей недвижимостью' 'автомобили' 'заняться образованием'
#  'сделка с подержанным автомобилем' 'получение образования' 'автомобиль'
#  'свадьба' 'получение дополнительного образования' 'покупка своего жилья'
#  'операции с недвижимостью' 'получение высшего образования'
#  'свой автомобиль' 'сделка с автомобилем' 'профильное образование'
#  'высшее образование' 'покупка жилья для сдачи' 'на покупку автомобиля'
#  'ремонт жилью' 'заняться высшим образованием']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count       21471
# unique         38
# top       свадьба
# freq          793
# Name: цель получения кредита, dtype: object
#
#
# Количество значений :
# свадьба                                   793
# на проведение свадьбы                     773
# сыграть свадьбу                           769
# операции с недвижимостью                  675
# покупка коммерческой недвижимости         662
# покупка жилья для сдачи                   652
# операции с жильем                         652
# операции с коммерческой недвижимостью     650
# покупка жилья                             646
# жилье                                     646
# покупка жилья для семьи                   638
# строительство собственной недвижимости    635
# недвижимость                              633
# операции со своей недвижимостью           627
# строительство жилой недвижимости          625
# покупка недвижимости                      621
# покупка своего жилья                      620
# строительство недвижимости                619
# ремонт жилью                              607
# покупка жилой недвижимости                606
# на покупку своего автомобиля              505
# заняться высшим образованием              496
# автомобиль                                494
# сделка с подержанным автомобилем          486
# свой автомобиль                           479
# на покупку подержанного автомобиля        478
# автомобили                                478
# на покупку автомобиля                     472
# приобретение автомобиля                   461
# дополнительное образование                460
# сделка с автомобилем                      455
# высшее образование                        452
# образование                               447
# получение дополнительного образования     447
# получение образования                     442
# профильное образование                    436
# получение высшего образования             426
# заняться образованием                     408
# Name: цель получения кредита, dtype: int64

# %% [markdown]
# Из уникальных значений и их количеств, а также пропусков, поставим задачи для подготовки данных.
#
# В признаке:
#
# 1)"количество детей в семье", присутствует значение : -1 количеством 47 и 20 количеством 76.
#
# 2)"уровень образования клиента" категориальный признак с разными регистрами.
#
# 3)"пол", присуствует третье значение 'XNA'. Это одна запись, будет удалена.
#
# 4)"общий трудовой стаж в днях", имеются отрицательные значения.
#
# 5)"цель получения кредита" требуется провести категоризацию признака
#
# 6)"возраст клиента в годах" присутствует значение 0 количеством 101
#
# 7)"общий трудовой стаж в днях" и "ежемесячный доход" имеют 2120 пропусков.
#
# 8)"общий трудовой стаж в днях" аномальные значения, не соответствуют действительности.
#
# 9)"идентификатор уровня образования" и "идентификатор семейного положения" соответствуют категориальным признакам "уровень образования клиента" и "семейное положение"

# %% [markdown]
# Начнём с первого. "количество детей в семье", присутствует значение : -1 количеством 47 и 20 количеством 76.

# %% [markdown]
# Для подробного исследования, воспользуемся полезной библиотекой pandas-profilling

# %%
# profile= pp.ProfileReport(df)
profile = ProfileReport(df, title="Pandas Profiling Report")

# profile.to_file('pandas_profile_test.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_file('инфо.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# В файле отчёта 'инфо.html' есть дополнительная информация: высокая корреляция между семейным положением и целью получения кредита, возраст клиента коррелирует с трудовым стажем, тип занятости коррелирует со стажем.

# %% [markdown]
# 47 значений -1, не так много. Преобразуем те записи, в колонке у которых количество детей -1, в 1. А те, что 20 добавим их к числу тех, у которых 2 детей, судя по характеристикам в файле, отличий критичных не наблюдается.

# %%
df[df['количество детей в семье'] == 20].describe()
# Out:
#        количество детей в семье  общий трудовой стаж в днях  \
# count                      76.0                   67.000000
# mean                       20.0                35779.535997
# std                         0.0               112008.279425
# min                        20.0               -11937.171389
# 25%                        20.0                -2629.663890
# 50%                        20.0                 -957.251278
# 75%                        20.0                 -478.364082
# max                        20.0               385267.263676
#
#        возраст клиента в годах  идентификатор уровня образования  \
# count                76.000000                         76.000000
# mean                 41.815789                          0.842105
# std                  12.065058                          0.433671
# min                   0.000000                          0.000000
# 25%                  33.750000                          1.000000
# 50%                  41.500000                          1.000000
# 75%                  50.000000                          1.000000
# max                  69.000000                          2.000000
#
#        идентификатор семейного положения  \
# count                          76.000000
# mean                            0.815789
# std                             1.363432
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             1.000000
# max                             4.000000
#
#        имел ли задолженность по возврату кредитов  ежемесячный доход
# count                                   76.000000          67.000000
# mean                                     0.105263      168720.526180
# std                                      0.308931       80851.738318
# min                                      0.000000       53971.576721
# 25%                                      0.000000      114668.631192
# 50%                                      0.000000      144544.530170
# 75%                                      0.000000      218033.697152
# max                                      1.000000      441721.334145

# %%
df[df['количество детей в семье'] == 2].describe()
# Out:
#        количество детей в семье  общий трудовой стаж в днях  \
# count                    2052.0                 1851.000000
# mean                        2.0                 1274.234500
# std                         0.0                35475.341365
# min                         2.0               -13039.072024
# 25%                         2.0                -2896.291250
# 50%                         2.0                -1634.342227
# 75%                         2.0                 -775.697378
# max                         2.0               397548.767244
#
#        возраст клиента в годах  идентификатор уровня образования  \
# count              2052.000000                       2052.000000
# mean                 35.769493                          0.788986
# std                   7.226231                          0.556698
# min                   0.000000                          0.000000
# 25%                  31.000000                          0.000000
# 50%                  35.000000                          1.000000
# 75%                  40.000000                          1.000000
# max                  64.000000                          3.000000
#
#        идентификатор семейного положения  \
# count                        2052.000000
# mean                            0.451267
# std                             0.971090
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             1.000000
# max                             4.000000
#
#        имел ли задолженность по возврату кредитов  ежемесячный доход
# count                                 2052.000000       1.851000e+03
# mean                                     0.094542       1.718522e+05
# std                                      0.292652       1.072317e+05
# min                                      0.000000       2.809288e+04
# 25%                                      0.000000       1.023172e+05
# 50%                                      0.000000       1.446486e+05
# 75%                                      0.000000       2.092035e+05
# max                                      1.000000       1.103455e+06

# %%
df[df['количество детей в семье'] == -1] = 1
df[df['количество детей в семье'] == 20] = 2

# %%
df[df['количество детей в семье'] == 20]
# Out:
# Empty DataFrame
# Columns: [количество детей в семье, общий трудовой стаж в днях, возраст клиента в годах, уровень образования клиента, идентификатор уровня образования, семейное положение, идентификатор семейного положения, пол, тип занятости, имел ли задолженность по возврату кредитов, ежемесячный доход, цель получения кредита]
# Index: []

# %% [markdown]
# Проверим на дубликаты и заметим, что появились дубликаты, с значениями 1 и 2, по всем признакам. Удалим их.

# %%
dupl = df[df.duplicated()]
df.drop(index = dupl.index, inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(index=df[df['уровень образования клиента'] == 1].index, inplace=True)
df.drop(index=df[df['уровень образования клиента'] == 2].index, inplace=True)

# %% [markdown]
# 3) Унифицируем Уровень образования

# %%
df['уровень образования клиента'] = df['уровень образования клиента'].str.lower()
df['уровень образования клиента'].value_counts()
# Out:
# среднее                15091
# высшее                  5228
# неоконченное высшее      741
# начальное                282
# ученая степень             6
# Name: уровень образования клиента, dtype: int64

# %% [markdown]
# 3) Удалим надоедливую одну запись со значением поля XNA.

# %%
df.drop(index=df[df['пол'] == 'XNA'].index, inplace=True)
df[df['пол'] == 'XNA']
# Out:
# Empty DataFrame
# Columns: [количество детей в семье, общий трудовой стаж в днях, возраст клиента в годах, уровень образования клиента, идентификатор уровня образования, семейное положение, идентификатор семейного положения, пол, тип занятости, имел ли задолженность по возврату кредитов, ежемесячный доход, цель получения кредита]
# Index: []

# %% [markdown]
# Видны записи по 2 и одной у по типам занятости : студент, безработынй и в декрете. удалим их.

# %%
type_job = ['безработный','студент','в декрете','предприниматель']

for i in type_job:
    df.drop(index= df[df['тип занятости'] == i].index, inplace=True)

# %% [markdown]
# Теперь посмотрим характеристики

# %%
out_df_uniq_propusk(df)
print(df.info())
# Out:
# *****************************************************************************************************************************
#
#
# Столбец :  количество детей в семье
# уникальные значения :  [1 0 3 2 4 5]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21341.000000
# mean         0.473689
# std          0.752206
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          5.000000
# Name: количество детей в семье, dtype: float64
#
#
# Количество значений :
# 0    14102
# 1     4808
# 2     2051
# 3      330
# 4       41
# 5        9
# Name: количество детей в семье, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  общий трудовой стаж в днях
# уникальные значения :  [-8437.67302776 -4024.80375385 -5623.42261023 ... -2113.3468877
#  -3112.4817052  -1984.50758853]
#
#
# пропуски :  2107
#
#
# Описательная статистика :
# count     19234.000000
# mean      63141.773911
# std      140913.583186
# min      -18388.949901
# 25%       -2747.277417
# 50%       -1204.164714
# 75%        -289.837414
# max      401755.400475
# Name: общий трудовой стаж в днях, dtype: float64
#
#
# Количество значений :
# -8437.673028      1
#  337451.389609    1
# -3112.788664      1
# -5135.928528      1
#  394214.527044    1
#                  ..
# -1083.159959      1
#  390769.069031    1
#  341277.435955    1
#  348798.745616    1
# -1984.507589      1
# Name: общий трудовой стаж в днях, Length: 19234, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  возраст клиента в годах
# уникальные значения :  [42 36 33 32 53 27 43 50 35 41 40 65 54 56 26 48 24 21 57 67 28 63 62 47
#  34 68 25 31 30 20 49 37 45 61 64 44 52 46 23 38 39 51  0 59 29 60 55 58
#  71 22 73 66 69 19 72 70 74 75]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21341.000000
# mean        43.288506
# std         12.578087
# min          0.000000
# 25%         33.000000
# 50%         42.000000
# 75%         53.000000
# max         75.000000
# Name: возраст клиента в годах, dtype: float64
#
#
# Количество значений :
# 35    613
# 41    602
# 40    601
# 34    595
# 38    594
# 42    591
# 33    577
# 39    570
# 31    554
# 36    552
# 29    542
# 44    541
# 48    535
# 30    534
# 37    530
# 43    509
# 50    508
# 49    505
# 32    505
# 28    501
# 45    493
# 27    489
# 52    483
# 56    479
# 47    477
# 54    473
# 46    467
# 53    457
# 58    455
# 57    453
# 51    446
# 55    441
# 59    440
# 26    406
# 60    373
# 25    356
# 61    352
# 62    348
# 63    268
# 24    262
# 64    260
# 23    251
# 65    194
# 22    182
# 66    182
# 67    167
# 21    110
# 0     100
# 68     99
# 69     83
# 70     65
# 71     58
# 20     51
# 72     33
# 19     14
# 73      8
# 74      6
# 75      1
# Name: возраст клиента в годах, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  уровень образования клиента
# уникальные значения :  ['высшее' 'среднее' 'неоконченное высшее' 'начальное' 'ученая степень']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count       21341
# unique          5
# top       среднее
# freq        15089
# Name: уровень образования клиента, dtype: object
#
#
# Количество значений :
# среднее                15089
# высшее                  5224
# неоконченное высшее      740
# начальное                282
# ученая степень             6
# Name: уровень образования клиента, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  идентификатор уровня образования
# уникальные значения :  [0 1 2 3 4]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21341.000000
# mean         0.817159
# std          0.549028
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          4.000000
# Name: идентификатор уровня образования, dtype: float64
#
#
# Количество значений :
# 1    15089
# 0     5224
# 2      740
# 3      282
# 4        6
# Name: идентификатор уровня образования, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  семейное положение
# уникальные значения :  ['женат / замужем' 'гражданский брак' 'вдовец / вдова' 'в разводе'
#  'Не женат / не замужем']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count               21341
# unique                  5
# top       женат / замужем
# freq                12263
# Name: семейное положение, dtype: object
#
#
# Количество значений :
# женат / замужем          12263
# гражданский брак          4143
# Не женат / не замужем     2795
# в разводе                 1189
# вдовец / вдова             951
# Name: семейное положение, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  идентификатор семейного положения
# уникальные значения :  [0 1 2 3 4]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21341.000000
# mean         0.974275
# std          1.421334
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          4.000000
# Name: идентификатор семейного положения, dtype: float64
#
#
# Количество значений :
# 0    12263
# 1     4143
# 4     2795
# 3     1189
# 2      951
# Name: идентификатор семейного положения, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  пол
# уникальные значения :  ['F' 'M']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count     21341
# unique        2
# top           F
# freq      14104
# Name: пол, dtype: object
#
#
# Количество значений :
# F    14104
# M     7237
# Name: пол, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  тип занятости
# уникальные значения :  ['сотрудник' 'пенсионер' 'компаньон' 'госслужащий']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count         21341
# unique            4
# top       сотрудник
# freq          11022
# Name: тип занятости, dtype: object
#
#
# Количество значений :
# сотрудник      11022
# компаньон       5048
# пенсионер       3820
# госслужащий     1451
# Name: тип занятости, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  имел ли задолженность по возврату кредитов
# уникальные значения :  [0 1]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21341.000000
# mean         0.081065
# std          0.272941
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: имел ли задолженность по возврату кредитов, dtype: float64
#
#
# Количество значений :
# 0    19611
# 1     1730
# Name: имел ли задолженность по возврату кредитов, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  ежемесячный доход
# уникальные значения :  [253875.6394526  112080.01410244 145885.95229686 ...  89672.56115303
#  244093.05050043  82047.41889948]
#
#
# пропуски :  2107
#
#
# Описательная статистика :
# count    1.923400e+04
# mean     1.674429e+05
# std      1.030854e+05
# min      2.066726e+04
# 25%      1.030109e+05
# 50%      1.450208e+05
# 75%      2.034396e+05
# max      2.265604e+06
# Name: ежемесячный доход, dtype: float64
#
#
# Количество значений :
# 253875.639453    1
# 114842.854099    1
# 235961.235873    1
# 124337.377229    1
# 131286.073745    1
#                 ..
# 168211.391366    1
# 254249.302632    1
# 149000.398440    1
# 172637.167134    1
# 82047.418899     1
# Name: ежемесячный доход, Length: 19234, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  цель получения кредита
# уникальные значения :  ['покупка жилья' 'приобретение автомобиля' 'дополнительное образование'
#  'сыграть свадьбу' 'операции с жильем' 'образование'
#  'на проведение свадьбы' 'покупка жилья для семьи' 'покупка недвижимости'
#  'покупка коммерческой недвижимости' 'покупка жилой недвижимости'
#  'строительство собственной недвижимости' 'недвижимость'
#  'строительство недвижимости' 'на покупку подержанного автомобиля'
#  'на покупку своего автомобиля' 'операции с коммерческой недвижимостью'
#  'строительство жилой недвижимости' 'жилье'
#  'операции со своей недвижимостью' 'автомобили' 'заняться образованием'
#  'сделка с подержанным автомобилем' 'получение образования' 'автомобиль'
#  'свадьба' 'получение дополнительного образования' 'покупка своего жилья'
#  'операции с недвижимостью' 'получение высшего образования'
#  'свой автомобиль' 'сделка с автомобилем' 'профильное образование'
#  'высшее образование' 'покупка жилья для сдачи' 'на покупку автомобиля'
#  'ремонт жилью' 'заняться высшим образованием']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count       21341
# unique         38
# top       свадьба
# freq          792
# Name: цель получения кредита, dtype: object
#
#
# Количество значений :
# свадьба                                   792
# на проведение свадьбы                     767
# сыграть свадьбу                           764
# операции с недвижимостью                  672
# покупка коммерческой недвижимости         659
# покупка жилья для сдачи                   649
# операции с жильем                         647
# операции с коммерческой недвижимостью     645
# жилье                                     641
# покупка жилья                             640
# покупка жилья для семьи                   637
# недвижимость                              631
# строительство собственной недвижимости    627
# операции со своей недвижимостью           623
# строительство жилой недвижимости          621
# строительство недвижимости                619
# покупка своего жилья                      619
# покупка недвижимости                      615
# ремонт жилью                              603
# покупка жилой недвижимости                601
# на покупку своего автомобиля              504
# заняться высшим образованием              496
# автомобиль                                490
# сделка с подержанным автомобилем          481
# автомобили                                476
# свой автомобиль                           474
# на покупку подержанного автомобиля        471
# на покупку автомобиля                     470
# приобретение автомобиля                   459
# сделка с автомобилем                      455
# дополнительное образование                455
# высшее образование                        446
# получение дополнительного образования     445
# образование                               442
# получение образования                     440
# профильное образование                    432
# получение высшего образования             425
# заняться образованием                     408
# Name: цель получения кредита, dtype: int64
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21341 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   количество детей в семье                    21341 non-null  int64
#  1   общий трудовой стаж в днях                  19234 non-null  float64
#  2   возраст клиента в годах                     21341 non-null  int64
#  3   уровень образования клиента                 21341 non-null  object
#  4   идентификатор уровня образования            21341 non-null  int64
#  5   семейное положение                          21341 non-null  object
#  6   идентификатор семейного положения           21341 non-null  int64
#  7   пол                                         21341 non-null  object
#  8   тип занятости                               21341 non-null  object
#  9   имел ли задолженность по возврату кредитов  21341 non-null  int64
#  10  ежемесячный доход                           19234 non-null  float64
#  11  цель получения кредита                      21341 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.1+ MB
# None

# %% [markdown]
# 4) Преобразуем значения "общий трудовой стаж" в абсолютные значения. Избавимся от минуса.

# %%
df['общий трудовой стаж в днях'] = df['общий трудовой стаж в днях'].round().abs()

# %% [markdown]
# 5) Проведём категоризацию признака 'цель получения кредита'

# %% [markdown]
# Токенизация и леммитизация

# %%
nltk.download('punkt') #пунктуация
nltk.download('stopwords') #стоп-слова
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Bair\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Bair\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
analyzer = MorphAnalyzer()

# посмотрим на стоп-слова для русского языка
stop_words = stopwords.words('russian')

# %%
df['цель получения кредита'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
#        'профильное образование', 'высшее образование',
#        'покупка жилья для сдачи', 'на покупку автомобиля', 'ремонт жилью',
#        'заняться высшим образованием'], dtype=object)

# %%
def tok_clear_stop_words_and_lemm(words):
    clear_words_tok_no_stop_lemm=[]
    words = word_tokenize(words)
    for word in words:
        if word not in stop_words:
            clear_words_tok_no_stop_lemm.append(analyzer.parse(word)[0].normal_form)
    return clear_words_tok_no_stop_lemm

# %%
df['лемматизация'] = df['цель получения кредита'].apply(tok_clear_stop_words_and_lemm)
df['лемматизация'].value_counts()
# Out:
# [автомобиль]                                  966
# [свадьба]                                     792
# [проведение, свадьба]                         767
# [сыграть, свадьба]                            764
# [операция, недвижимость]                      672
# [покупка, коммерческий, недвижимость]         659
# [покупка, жильё, сдача]                       649
# [операция, жильё]                             647
# [операция, коммерческий, недвижимость]        645
# [жильё]                                       641
# [покупка, жильё]                              640
# [покупка, жильё, семья]                       637
# [недвижимость]                                631
# [строительство, собственный, недвижимость]    627
# [операция, свой, недвижимость]                623
# [строительство, жилой, недвижимость]          621
# [покупка, свой, жильё]                        619
# [строительство, недвижимость]                 619
# [покупка, недвижимость]                       615
# [ремонт, жильё]                               603
# [покупка, жилой, недвижимость]                601
# [покупка, свой, автомобиль]                   504
# [заняться, высокий, образование]              496
# [сделка, подержать, автомобиль]               481
# [свой, автомобиль]                            474
# [покупка, подержать, автомобиль]              471
# [покупка, автомобиль]                         470
# [приобретение, автомобиль]                    459
# [сделка, автомобиль]                          455
# [дополнительный, образование]                 455
# [высокий, образование]                        446
# [получение, дополнительный, образование]      445
# [образование]                                 442
# [получение, образование]                      440
# [профильный, образование]                     432
# [получение, высокий, образование]             425
# [заняться, образование]                       408
# Name: лемматизация, dtype: int64

# %%
def purpose_to_cat(lemmas):
    cat_cred = ''
    if ('жилье' in lemmas) or ('жильё' in lemmas) or ('недвижимость' in lemmas):
        cat_cred = 'жилищное кредитование'
    if 'коммерческий' in lemmas:
        cat_cred = 'развитие бизнеса'
    if ('свадьба' in lemmas) or ('строительство' in lemmas) or ('ремонт' in lemmas):
        cat_cred = 'потребительский кредит'
    if ('образование' in lemmas):
        cat_cred = 'образовательный кредит'
    if ('автомобиль' in lemmas):
        cat_cred = 'автокредитование'
    return cat_cred

df['категория кредита'] = df['лемматизация'].apply(purpose_to_cat)

# %%
df['категория кредита'] = df['лемматизация'].apply(purpose_to_cat)

# %%
df['категория кредита'].value_counts()
# Out:
# жилищное кредитование     6975
# потребительский кредит    4793
# автокредитование          4280
# образовательный кредит    3989
# развитие бизнеса          1304
# Name: категория кредита, dtype: int64

# %%
df.drop(columns= 'лемматизация', inplace=True)

# %%
df.drop(columns='цель получения кредита',inplace=True)

# %% [markdown]
# Создадим дополнительный файлик информации нашего датафрэйма для просмотра статистики.

# %%
profile_posle_1 = ProfileReport(df, title="Pandas Profiling Report")

# %%
profile_posle_1.to_file('инфо_2.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# найдём дубликаты

# %%
df.duplicated().sum()
# Out:
# 258

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 6) Найдём записи у которых возраст, равен 0

# %%
df[df['возраст клиента в годах'] == 0]
# Out:
#        количество детей в семье  общий трудовой стаж в днях  \
# 99                            0                    346542.0
# 149                           0                      2664.0
# 270                           3                      1873.0
# 578                           0                    397857.0
# 1040                          0                      1158.0
# ...                         ...                         ...
# 19371                         1                      2356.0
# 20462                         0                    338735.0
# 20577                         0                    331741.0
# 21179                         2                       109.0
# 21313                         0                      1268.0
#
#        возраст клиента в годах уровень образования клиента  \
# 99                           0                     среднее
# 149                          0                     среднее
# 270                          0                     среднее
# 578                          0                     среднее
# 1040                         0                      высшее
# ...                        ...                         ...
# 19371                        0                      высшее
# 20462                        0                     среднее
# 20577                        0                     среднее
# 21179                        0                      высшее
# 21313                        0                     среднее
#
#        идентификатор уровня образования     семейное положение  \
# 99                                    1        женат / замужем
# 149                                   1              в разводе
# 270                                   1        женат / замужем
# 578                                   1        женат / замужем
# 1040                                  0              в разводе
# ...                                 ...                    ...
# 19371                                 0        женат / замужем
# 20462                                 1        женат / замужем
# 20577                                 1  Не женат / не замужем
# 21179                                 0        женат / замужем
# 21313                                 1  Не женат / не замужем
#
#        идентификатор семейного положения пол тип занятости  \
# 99                                     0   F     пенсионер
# 149                                    3   F     сотрудник
# 270                                    0   F     сотрудник
# 578                                    0   F     пенсионер
# 1040                                   3   F     компаньон
# ...                                  ...  ..           ...
# 19371                                  0   F     компаньон
# 20462                                  0   F     пенсионер
# 20577                                  4   F     пенсионер
# 21179                                  0   M     компаньон
# 21313                                  4   M     сотрудник
#
#        имел ли задолженность по возврату кредитов  ежемесячный доход  \
# 99                                              0       71291.522491
# 149                                             0       70176.435951
# 270                                             0      102166.458894
# 578                                             0       97620.687042
# 1040                                            0      303994.134987
# ...                                           ...                ...
# 19371                                           0       77936.218285
# 20462                                           0      259193.920299
# 20577                                           0      129788.762899
# 21179                                           0      240702.007382
# 21313                                           0      152419.184851
#
#             категория кредита
# 99           автокредитование
# 149     жилищное кредитование
# 270    потребительский кредит
# 578    потребительский кредит
# 1040         автокредитование
# ...                       ...
# 19371        автокредитование
# 20462   жилищное кредитование
# 20577   жилищное кредитование
# 21179  потребительский кредит
# 21313   жилищное кредитование
#
# [99 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21083 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   количество детей в семье                    21083 non-null  int64
#  1   общий трудовой стаж в днях                  19234 non-null  float64
#  2   возраст клиента в годах                     21083 non-null  int64
#  3   уровень образования клиента                 21083 non-null  object
#  4   идентификатор уровня образования            21083 non-null  int64
#  5   семейное положение                          21083 non-null  object
#  6   идентификатор семейного положения           21083 non-null  int64
#  7   пол                                         21083 non-null  object
#  8   тип занятости                               21083 non-null  object
#  9   имел ли задолженность по возврату кредитов  21083 non-null  int64
#  10  ежемесячный доход                           19234 non-null  float64
#  11  категория кредита                           21083 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.1+ MB

# %%
s = df[df['возраст клиента в годах'] == 0]

# %%
s['возраст клиента в годах'] = np.nan
# Out:
# C:\Users\Bair\AppData\Local\Temp\ipykernel_6624\3229382100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['возраст клиента в годах'] = np.nan

# %%
s
# Out:
#        количество детей в семье  общий трудовой стаж в днях  \
# 99                            0                    346542.0
# 149                           0                      2664.0
# 270                           3                      1873.0
# 578                           0                    397857.0
# 1040                          0                      1158.0
# ...                         ...                         ...
# 19371                         1                      2356.0
# 20462                         0                    338735.0
# 20577                         0                    331741.0
# 21179                         2                       109.0
# 21313                         0                      1268.0
#
#        возраст клиента в годах уровень образования клиента  \
# 99                         NaN                     среднее
# 149                        NaN                     среднее
# 270                        NaN                     среднее
# 578                        NaN                     среднее
# 1040                       NaN                      высшее
# ...                        ...                         ...
# 19371                      NaN                      высшее
# 20462                      NaN                     среднее
# 20577                      NaN                     среднее
# 21179                      NaN                      высшее
# 21313                      NaN                     среднее
#
#        идентификатор уровня образования     семейное положение  \
# 99                                    1        женат / замужем
# 149                                   1              в разводе
# 270                                   1        женат / замужем
# 578                                   1        женат / замужем
# 1040                                  0              в разводе
# ...                                 ...                    ...
# 19371                                 0        женат / замужем
# 20462                                 1        женат / замужем
# 20577                                 1  Не женат / не замужем
# 21179                                 0        женат / замужем
# 21313                                 1  Не женат / не замужем
#
#        идентификатор семейного положения пол тип занятости  \
# 99                                     0   F     пенсионер
# 149                                    3   F     сотрудник
# 270                                    0   F     сотрудник
# 578                                    0   F     пенсионер
# 1040                                   3   F     компаньон
# ...                                  ...  ..           ...
# 19371                                  0   F     компаньон
# 20462                                  0   F     пенсионер
# 20577                                  4   F     пенсионер
# 21179                                  0   M     компаньон
# 21313                                  4   M     сотрудник
#
#        имел ли задолженность по возврату кредитов  ежемесячный доход  \
# 99                                              0       71291.522491
# 149                                             0       70176.435951
# 270                                             0      102166.458894
# 578                                             0       97620.687042
# 1040                                            0      303994.134987
# ...                                           ...                ...
# 19371                                           0       77936.218285
# 20462                                           0      259193.920299
# 20577                                           0      129788.762899
# 21179                                           0      240702.007382
# 21313                                           0      152419.184851
#
#             категория кредита
# 99           автокредитование
# 149     жилищное кредитование
# 270    потребительский кредит
# 578    потребительский кредит
# 1040         автокредитование
# ...                       ...
# 19371        автокредитование
# 20462   жилищное кредитование
# 20577   жилищное кредитование
# 21179  потребительский кредит
# 21313   жилищное кредитование
#
# [99 rows x 12 columns]

# %%
df1 = pd.concat([s, df], ignore_index=True)
df1
# Out:
#        количество детей в семье  общий трудовой стаж в днях  \
# 0                             0                    346542.0
# 1                             0                      2664.0
# 2                             3                      1873.0
# 3                             0                    397857.0
# 4                             0                      1158.0
# ...                         ...                         ...
# 21177                         1                      4529.0
# 21178                         0                    343937.0
# 21179                         1                      2113.0
# 21180                         3                      3112.0
# 21181                         2                      1985.0
#
#        возраст клиента в годах уровень образования клиента  \
# 0                          NaN                     среднее
# 1                          NaN                     среднее
# 2                          NaN                     среднее
# 3                          NaN                     среднее
# 4                          NaN                      высшее
# ...                        ...                         ...
# 21177                     43.0                     среднее
# 21178                     67.0                     среднее
# 21179                     38.0                     среднее
# 21180                     38.0                     среднее
# 21181                     40.0                     среднее
#
#        идентификатор уровня образования семейное положение  \
# 0                                     1    женат / замужем
# 1                                     1          в разводе
# 2                                     1    женат / замужем
# 3                                     1    женат / замужем
# 4                                     0          в разводе
# ...                                 ...                ...
# 21177                                 1   гражданский брак
# 21178                                 1    женат / замужем
# 21179                                 1   гражданский брак
# 21180                                 1    женат / замужем
# 21181                                 1    женат / замужем
#
#        идентификатор семейного положения пол тип занятости  \
# 0                                      0   F     пенсионер
# 1                                      3   F     сотрудник
# 2                                      0   F     сотрудник
# 3                                      0   F     пенсионер
# 4                                      3   F     компаньон
# ...                                  ...  ..           ...
# 21177                                  1   F     компаньон
# 21178                                  0   F     пенсионер
# 21179                                  1   M     сотрудник
# 21180                                  0   M     сотрудник
# 21181                                  0   F     сотрудник
#
#        имел ли задолженность по возврату кредитов  ежемесячный доход  \
# 0                                               0       71291.522491
# 1                                               0       70176.435951
# 2                                               0      102166.458894
# 3                                               0       97620.687042
# 4                                               0      303994.134987
# ...                                           ...                ...
# 21177                                           0      224791.862382
# 21178                                           0      155999.806512
# 21179                                           1       89672.561153
# 21180                                           1      244093.050500
# 21181                                           0       82047.418899
#
#             категория кредита
# 0            автокредитование
# 1       жилищное кредитование
# 2      потребительский кредит
# 3      потребительский кредит
# 4            автокредитование
# ...                       ...
# 21177   жилищное кредитование
# 21178        автокредитование
# 21179   жилищное кредитование
# 21180        автокредитование
# 21181        автокредитование
#
# [21182 rows x 12 columns]

# %%
df1[df1['возраст клиента в годах'] == 0]
# Out:
#        количество детей в семье  общий трудовой стаж в днях  \
# 198                           0                    346542.0
# 248                           0                      2664.0
# 369                           3                      1873.0
# 675                           0                    397857.0
# 1129                          0                      1158.0
# ...                         ...                         ...
# 19100                         1                      2356.0
# 20147                         0                    338735.0
# 20261                         0                    331741.0
# 20848                         2                       109.0
# 20979                         0                      1268.0
#
#        возраст клиента в годах уровень образования клиента  \
# 198                        0.0                     среднее
# 248                        0.0                     среднее
# 369                        0.0                     среднее
# 675                        0.0                     среднее
# 1129                       0.0                      высшее
# ...                        ...                         ...
# 19100                      0.0                      высшее
# 20147                      0.0                     среднее
# 20261                      0.0                     среднее
# 20848                      0.0                      высшее
# 20979                      0.0                     среднее
#
#        идентификатор уровня образования     семейное положение  \
# 198                                   1        женат / замужем
# 248                                   1              в разводе
# 369                                   1        женат / замужем
# 675                                   1        женат / замужем
# 1129                                  0              в разводе
# ...                                 ...                    ...
# 19100                                 0        женат / замужем
# 20147                                 1        женат / замужем
# 20261                                 1  Не женат / не замужем
# 20848                                 0        женат / замужем
# 20979                                 1  Не женат / не замужем
#
#        идентификатор семейного положения пол тип занятости  \
# 198                                    0   F     пенсионер
# 248                                    3   F     сотрудник
# 369                                    0   F     сотрудник
# 675                                    0   F     пенсионер
# 1129                                   3   F     компаньон
# ...                                  ...  ..           ...
# 19100                                  0   F     компаньон
# 20147                                  0   F     пенсионер
# 20261                                  4   F     пенсионер
# 20848                                  0   M     компаньон
# 20979                                  4   M     сотрудник
#
#        имел ли задолженность по возврату кредитов  ежемесячный доход  \
# 198                                             0       71291.522491
# 248                                             0       70176.435951
# 369                                             0      102166.458894
# 675                                             0       97620.687042
# 1129                                            0      303994.134987
# ...                                           ...                ...
# 19100                                           0       77936.218285
# 20147                                           0      259193.920299
# 20261                                           0      129788.762899
# 20848                                           0      240702.007382
# 20979                                           0      152419.184851
#
#             категория кредита
# 198          автокредитование
# 248     жилищное кредитование
# 369    потребительский кредит
# 675    потребительский кредит
# 1129         автокредитование
# ...                       ...
# 19100        автокредитование
# 20147   жилищное кредитование
# 20261   жилищное кредитование
# 20848  потребительский кредит
# 20979   жилищное кредитование
#
# [99 rows x 12 columns]

# %%
df1.drop(index=df1[df1['возраст клиента в годах'] == 0].index, inplace=True)

# %%
df1[df1['возраст клиента в годах'].isna()]
# Out:
#     количество детей в семье  общий трудовой стаж в днях  \
# 0                          0                    346542.0
# 1                          0                      2664.0
# 2                          3                      1873.0
# 3                          0                    397857.0
# 4                          0                      1158.0
# ..                       ...                         ...
# 94                         1                      2356.0
# 95                         0                    338735.0
# 96                         0                    331741.0
# 97                         2                       109.0
# 98                         0                      1268.0
#
#     возраст клиента в годах уровень образования клиента  \
# 0                       NaN                     среднее
# 1                       NaN                     среднее
# 2                       NaN                     среднее
# 3                       NaN                     среднее
# 4                       NaN                      высшее
# ..                      ...                         ...
# 94                      NaN                      высшее
# 95                      NaN                     среднее
# 96                      NaN                     среднее
# 97                      NaN                      высшее
# 98                      NaN                     среднее
#
#     идентификатор уровня образования     семейное положение  \
# 0                                  1        женат / замужем
# 1                                  1              в разводе
# 2                                  1        женат / замужем
# 3                                  1        женат / замужем
# 4                                  0              в разводе
# ..                               ...                    ...
# 94                                 0        женат / замужем
# 95                                 1        женат / замужем
# 96                                 1  Не женат / не замужем
# 97                                 0        женат / замужем
# 98                                 1  Не женат / не замужем
#
#     идентификатор семейного положения пол тип занятости  \
# 0                                   0   F     пенсионер
# 1                                   3   F     сотрудник
# 2                                   0   F     сотрудник
# 3                                   0   F     пенсионер
# 4                                   3   F     компаньон
# ..                                ...  ..           ...
# 94                                  0   F     компаньон
# 95                                  0   F     пенсионер
# 96                                  4   F     пенсионер
# 97                                  0   M     компаньон
# 98                                  4   M     сотрудник
#
#     имел ли задолженность по возврату кредитов  ежемесячный доход  \
# 0                                            0       71291.522491
# 1                                            0       70176.435951
# 2                                            0      102166.458894
# 3                                            0       97620.687042
# 4                                            0      303994.134987
# ..                                         ...                ...
# 94                                           0       77936.218285
# 95                                           0      259193.920299
# 96                                           0      129788.762899
# 97                                           0      240702.007382
# 98                                           0      152419.184851
#
#          категория кредита
# 0         автокредитование
# 1    жилищное кредитование
# 2   потребительский кредит
# 3   потребительский кредит
# 4         автокредитование
# ..                     ...
# 94        автокредитование
# 95   жилищное кредитование
# 96   жилищное кредитование
# 97  потребительский кредит
# 98   жилищное кредитование
#
# [99 rows x 12 columns]

# %%
df1.isna().sum()
# Out:
# количество детей в семье                         0
# общий трудовой стаж в днях                    1849
# возраст клиента в годах                         99
# уровень образования клиента                      0
# идентификатор уровня образования                 0
# семейное положение                               0
# идентификатор семейного положения                0
# пол                                              0
# тип занятости                                    0
# имел ли задолженность по возврату кредитов       0
# ежемесячный доход                             1849
# категория кредита                                0
# dtype: int64

# %% [markdown]
# Заполним пропущенные значение возраста.

# %%
df1
# Out:
#        количество детей в семье  общий трудовой стаж в днях  \
# 0                             0                    346542.0
# 1                             0                      2664.0
# 2                             3                      1873.0
# 3                             0                    397857.0
# 4                             0                      1158.0
# ...                         ...                         ...
# 21177                         1                      4529.0
# 21178                         0                    343937.0
# 21179                         1                      2113.0
# 21180                         3                      3112.0
# 21181                         2                      1985.0
#
#        возраст клиента в годах уровень образования клиента  \
# 0                          NaN                     среднее
# 1                          NaN                     среднее
# 2                          NaN                     среднее
# 3                          NaN                     среднее
# 4                          NaN                      высшее
# ...                        ...                         ...
# 21177                     43.0                     среднее
# 21178                     67.0                     среднее
# 21179                     38.0                     среднее
# 21180                     38.0                     среднее
# 21181                     40.0                     среднее
#
#        идентификатор уровня образования семейное положение  \
# 0                                     1    женат / замужем
# 1                                     1          в разводе
# 2                                     1    женат / замужем
# 3                                     1    женат / замужем
# 4                                     0          в разводе
# ...                                 ...                ...
# 21177                                 1   гражданский брак
# 21178                                 1    женат / замужем
# 21179                                 1   гражданский брак
# 21180                                 1    женат / замужем
# 21181                                 1    женат / замужем
#
#        идентификатор семейного положения пол тип занятости  \
# 0                                      0   F     пенсионер
# 1                                      3   F     сотрудник
# 2                                      0   F     сотрудник
# 3                                      0   F     пенсионер
# 4                                      3   F     компаньон
# ...                                  ...  ..           ...
# 21177                                  1   F     компаньон
# 21178                                  0   F     пенсионер
# 21179                                  1   M     сотрудник
# 21180                                  0   M     сотрудник
# 21181                                  0   F     сотрудник
#
#        имел ли задолженность по возврату кредитов  ежемесячный доход  \
# 0                                               0       71291.522491
# 1                                               0       70176.435951
# 2                                               0      102166.458894
# 3                                               0       97620.687042
# 4                                               0      303994.134987
# ...                                           ...                ...
# 21177                                           0      224791.862382
# 21178                                           0      155999.806512
# 21179                                           1       89672.561153
# 21180                                           1      244093.050500
# 21181                                           0       82047.418899
#
#             категория кредита
# 0            автокредитование
# 1       жилищное кредитование
# 2      потребительский кредит
# 3      потребительский кредит
# 4            автокредитование
# ...                       ...
# 21177   жилищное кредитование
# 21178        автокредитование
# 21179   жилищное кредитование
# 21180        автокредитование
# 21181        автокредитование
#
# [21083 rows x 12 columns]

# %%
from sklearn.impute import KNNImputer
from math import nan

imp_nan = KNNImputer(missing_values=np.nan, n_neighbors=5)

# %%
ur = df1['уровень образования клиента']

# %%
ur
# Out:
# 0        среднее
# 1        среднее
# 2        среднее
# 3        среднее
# 4         высшее
#           ...
# 21177    среднее
# 21178    среднее
# 21179    среднее
# 21180    среднее
# 21181    среднее
# Name: уровень образования клиента, Length: 21083, dtype: object

# %%
df1['уровень образования клиента'].isnull().sum()
# Out:
# 0

# %%
df1.drop(columns='уровень образования клиента', inplace=True)

# %%
semya = df1['семейное положение']

# %%
semya
# Out:
# 0         женат / замужем
# 1               в разводе
# 2         женат / замужем
# 3         женат / замужем
# 4               в разводе
#                ...
# 21177    гражданский брак
# 21178     женат / замужем
# 21179    гражданский брак
# 21180     женат / замужем
# 21181     женат / замужем
# Name: семейное положение, Length: 21083, dtype: object

# %%
df1.drop(columns='семейное положение', inplace=True)

# %%
df1['пол'].replace({'F': 0, 'M':1}, inplace=True)

# %%
df1['тип занятости'].replace({'сотрудник': 0, 'компаньон':1, 'госслужащий': 2, 'пенсионер': 3}, inplace=True)

# %%
df1['категория кредита'].replace({'жилищное кредитование':0, 'потребительский кредит':1, 'автокредитование':2, 'образовательный кредит':3, 'развитие бизнеса':4}, inplace=True)

# %%
df1['категория кредита'].value_counts()
# Out:
# 0    6856
# 1    4741
# 2    4244
# 3    3939
# 4    1303
# Name: категория кредита, dtype: int64

# %%
df1.columns
# Out:
# Index(['количество детей в семье', 'общий трудовой стаж в днях',
#        'возраст клиента в годах', 'идентификатор уровня образования',
#        'идентификатор семейного положения', 'пол', 'тип занятости',
#        'имел ли задолженность по возврату кредитов', 'ежемесячный доход',
#        'категория кредита'],
#       dtype='object')

# %%
df1
# Out:
#        количество детей в семье  общий трудовой стаж в днях  \
# 0                             0                    346542.0
# 1                             0                      2664.0
# 2                             3                      1873.0
# 3                             0                    397857.0
# 4                             0                      1158.0
# ...                         ...                         ...
# 21177                         1                      4529.0
# 21178                         0                    343937.0
# 21179                         1                      2113.0
# 21180                         3                      3112.0
# 21181                         2                      1985.0
#
#        возраст клиента в годах  идентификатор уровня образования  \
# 0                          NaN                                 1
# 1                          NaN                                 1
# 2                          NaN                                 1
# 3                          NaN                                 1
# 4                          NaN                                 0
# ...                        ...                               ...
# 21177                     43.0                                 1
# 21178                     67.0                                 1
# 21179                     38.0                                 1
# 21180                     38.0                                 1
# 21181                     40.0                                 1
#
#        идентификатор семейного положения  пол  тип занятости  \
# 0                                      0    0              3
# 1                                      3    0              0
# 2                                      0    0              0
# 3                                      0    0              3
# 4                                      3    0              1
# ...                                  ...  ...            ...
# 21177                                  1    0              1
# 21178                                  0    0              3
# 21179                                  1    1              0
# 21180                                  0    1              0
# 21181                                  0    0              0
#
#        имел ли задолженность по возврату кредитов  ежемесячный доход  \
# 0                                               0       71291.522491
# 1                                               0       70176.435951
# 2                                               0      102166.458894
# 3                                               0       97620.687042
# 4                                               0      303994.134987
# ...                                           ...                ...
# 21177                                           0      224791.862382
# 21178                                           0      155999.806512
# 21179                                           1       89672.561153
# 21180                                           1      244093.050500
# 21181                                           0       82047.418899
#
#        категория кредита
# 0                      2
# 1                      0
# 2                      1
# 3                      1
# 4                      2
# ...                  ...
# 21177                  0
# 21178                  2
# 21179                  0
# 21180                  2
# 21181                  2
#
# [21083 rows x 10 columns]

# %%
result = imp_nan.fit_transform(df1)

# %%
df2 = pd.DataFrame(data=result, columns= df1.columns)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21083 entries, 0 to 21082
# Data columns (total 10 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   количество детей в семье                    21083 non-null  float64
#  1   общий трудовой стаж в днях                  21083 non-null  float64
#  2   возраст клиента в годах                     21083 non-null  float64
#  3   идентификатор уровня образования            21083 non-null  float64
#  4   идентификатор семейного положения           21083 non-null  float64
#  5   пол                                         21083 non-null  float64
#  6   тип занятости                               21083 non-null  float64
#  7   имел ли задолженность по возврату кредитов  21083 non-null  float64
#  8   ежемесячный доход                           21083 non-null  float64
#  9   категория кредита                           21083 non-null  float64
# dtypes: float64(10)
# memory usage: 1.6 MB

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2['пол'].replace({0:'Ж', 1:'М'}, inplace=True)

# %%
df2['тип занятости'].replace({0: 'сотрудник', 1:'компаньон', 2: 'госслужащий', 3: 'пенсионер'}, inplace=True)

# %%
df2['категория кредита'].replace({0:'жилищное кредитование', 1:'потребительский кредит', 2:'автокредитование', 3:'образовательный кредит', 4:'развитие бизнеса'}, inplace=True)

# %%
df2
# Out:
#        количество детей в семье  общий трудовой стаж в днях  \
# 0                           0.0                    346542.0
# 1                           0.0                      2664.0
# 2                           3.0                      1873.0
# 3                           0.0                    397857.0
# 4                           0.0                      1158.0
# ...                         ...                         ...
# 21078                       1.0                      4529.0
# 21079                       0.0                    343937.0
# 21080                       1.0                      2113.0
# 21081                       3.0                      3112.0
# 21082                       2.0                      1985.0
#
#        возраст клиента в годах  идентификатор уровня образования  \
# 0                         51.8                               1.0
# 1                         52.6                               1.0
# 2                         32.0                               1.0
# 3                         60.8                               1.0
# 4                         44.8                               0.0
# ...                        ...                               ...
# 21078                     43.0                               1.0
# 21079                     67.0                               1.0
# 21080                     38.0                               1.0
# 21081                     38.0                               1.0
# 21082                     40.0                               1.0
#
#        идентификатор семейного положения пол тип занятости  \
# 0                                    0.0   Ж     пенсионер
# 1                                    3.0   Ж     сотрудник
# 2                                    0.0   Ж     сотрудник
# 3                                    0.0   Ж     пенсионер
# 4                                    3.0   Ж     компаньон
# ...                                  ...  ..           ...
# 21078                                1.0   Ж     компаньон
# 21079                                0.0   Ж     пенсионер
# 21080                                1.0   М     сотрудник
# 21081                                0.0   М     сотрудник
# 21082                                0.0   Ж     сотрудник
#
#        имел ли задолженность по возврату кредитов  ежемесячный доход  \
# 0                                             0.0       71291.522491
# 1                                             0.0       70176.435951
# 2                                             0.0      102166.458894
# 3                                             0.0       97620.687042
# 4                                             0.0      303994.134987
# ...                                           ...                ...
# 21078                                         0.0      224791.862382
# 21079                                         0.0      155999.806512
# 21080                                         1.0       89672.561153
# 21081                                         1.0      244093.050500
# 21082                                         0.0       82047.418899
#
#             категория кредита
# 0            автокредитование
# 1       жилищное кредитование
# 2      потребительский кредит
# 3      потребительский кредит
# 4            автокредитование
# ...                       ...
# 21078   жилищное кредитование
# 21079        автокредитование
# 21080   жилищное кредитование
# 21081        автокредитование
# 21082        автокредитование
#
# [21083 rows x 10 columns]

# %%
df2['идентификатор уровня образования'].replace({1:'среднее', 0:'высшее',2:'неоконченное высшее',3:'начальное',4:'ученая степень'},inplace=True)

# %%
df2['идентификатор семейного положения'].replace({0:'женат / замужем', 1:'гражданский брак', 4:'Не женат / не замужем', 3:'в разводе', 2:'вдовец / вдова'}, inplace=True)

# %%
out_df_uniq_propusk(df2)
# Out:
# *****************************************************************************************************************************
#
#
# Столбец :  количество детей в семье
# уникальные значения :  [0. 3. 2. 1. 4. 5.]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21083.000000
# mean         0.476735
# std          0.754059
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          5.000000
# Name: количество детей в семье, dtype: float64
#
#
# Количество значений :
# 0.0    13890
# 1.0     4773
# 2.0     2041
# 3.0      329
# 4.0       41
# 5.0        9
# Name: количество детей в семье, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  общий трудовой стаж в днях
# уникальные значения :  [346542.    2664.    1873.  ...   1397.2 373996.  343937. ]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count     21083.000000
# mean      66790.865712
# std      138646.172719
# min          24.000000
# 25%         989.000000
# 50%        2234.000000
# 75%        5432.000000
# max      401755.000000
# Name: общий трудовой стаж в днях, dtype: float64
#
#
# Количество значений :
# 200.0       15
# 206.0       14
# 220.0       14
# 1482.0      13
# 477.0       12
#             ..
# 373793.0     1
# 147801.4     1
# 400032.0     1
# 396070.0     1
# 343937.0     1
# Name: общий трудовой стаж в днях, Length: 10554, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  возраст клиента в годах
# уникальные значения :  [51.8 52.6 32.  60.8 44.8 39.  61.8 47.4 38.8 58.8 55.  38.2 56.4 43.8
#  34.8 41.2 40.4 32.6 58.2 33.4 49.  27.  36.2 63.2 61.  30.8 42.8 33.6
#  57.4 38.4 35.6 29.6 50.2 53.4 34.6 54.  31.4 42.  33.2 46.  51.2 58.4
#  39.4 36.8 37.  43.  44.6 47.8 39.2 32.2 47.6 59.2 41.6 40.  62.2 46.4
#  36.4 46.6 42.2 37.2 31.8 39.6 29.8 59.4 40.2 42.6 61.2 49.4 60.2 35.4
#  35.8 43.2 41.8 42.4 35.  62.4 53.  57.8 25.4 36.  33.  50.  41.  65.
#  56.  26.  48.  24.  21.  57.  67.  28.  63.  62.  47.  34.  68.  25.
#  31.  30.  20.  45.  64.  44.  52.  23.  38.  51.  59.  29.  60.  58.
#  71.  22.  73.  66.  69.  19.  72.  70.  74.  75. ]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21083.000000
# mean        43.435792
# std         12.236824
# min         19.000000
# 25%         33.000000
# 50%         42.000000
# 75%         53.000000
# max         75.000000
# Name: возраст клиента в годах, dtype: float64
#
#
# Количество значений :
# 35.0    606
# 40.0    600
# 41.0    598
# 34.0    594
# 38.0    590
#        ...
# 47.6      1
# 39.2      1
# 47.8      1
# 44.6      1
# 75.0      1
# Name: возраст клиента в годах, Length: 122, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  идентификатор уровня образования
# уникальные значения :  ['среднее' 'высшее' 'неоконченное высшее' 'начальное' 'ученая степень']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count       21083
# unique          5
# top       среднее
# freq        14855
# Name: идентификатор уровня образования, dtype: object
#
#
# Количество значений :
# среднее                14855
# высшее                  5200
# неоконченное высшее      740
# начальное                282
# ученая степень             6
# Name: идентификатор уровня образования, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  идентификатор семейного положения
# уникальные значения :  ['женат / замужем' 'в разводе' 'Не женат / не замужем' 'вдовец / вдова'
#  'гражданский брак']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count               21083
# unique                  5
# top       женат / замужем
# freq                12080
# Name: идентификатор семейного положения, dtype: object
#
#
# Количество значений :
# женат / замужем          12080
# гражданский брак          4099
# Не женат / не замужем     2778
# в разводе                 1187
# вдовец / вдова             939
# Name: идентификатор семейного положения, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  пол
# уникальные значения :  ['Ж' 'М']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count     21083
# unique        2
# top           Ж
# freq      13898
# Name: пол, dtype: object
#
#
# Количество значений :
# Ж    13898
# М     7185
# Name: пол, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  тип занятости
# уникальные значения :  ['пенсионер' 'сотрудник' 'компаньон' 'госслужащий']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count         21083
# unique            4
# top       сотрудник
# freq          10886
# Name: тип занятости, dtype: object
#
#
# Количество значений :
# сотрудник      10886
# компаньон       5015
# пенсионер       3737
# госслужащий     1445
# Name: тип занятости, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  имел ли задолженность по возврату кредитов
# уникальные значения :  [0. 1.]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    21083.000000
# mean         0.082009
# std          0.274385
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: имел ли задолженность по возврату кредитов, dtype: float64
#
#
# Количество значений :
# 0.0    19354
# 1.0     1729
# Name: имел ли задолженность по возврату кредитов, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  ежемесячный доход
# уникальные значения :  [ 71291.52249056  70176.43595051 102166.45889365 ...  89672.56115303
#  244093.05050043  82047.41889948]
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count    2.108300e+04
# mean     1.672872e+05
# std      9.967360e+04
# min      2.066726e+04
# 25%      1.056851e+05
# 50%      1.465143e+05
# 75%      2.019316e+05
# max      2.265604e+06
# Name: ежемесячный доход, dtype: float64
#
#
# Количество значений :
# 71291.522491     1
# 267994.491416    1
# 143318.912768    1
# 188960.186782    1
# 159897.368301    1
#                 ..
# 279665.576667    1
# 151395.454567    1
# 125064.838029    1
# 154982.034497    1
# 82047.418899     1
# Name: ежемесячный доход, Length: 21083, dtype: int64
#
#
# *****************************************************************************************************************************
#
#
# Столбец :  категория кредита
# уникальные значения :  ['автокредитование' 'жилищное кредитование' 'потребительский кредит'
#  'образовательный кредит' 'развитие бизнеса']
#
#
# пропуски :  0
#
#
# Описательная статистика :
# count                     21083
# unique                        5
# top       жилищное кредитование
# freq                       6856
# Name: категория кредита, dtype: object
#
#
# Количество значений :
# жилищное кредитование     6856
# потребительский кредит    4741
# автокредитование          4244
# образовательный кредит    3939
# развитие бизнеса          1303
# Name: категория кредита, dtype: int64

# %%
profile_posle_2 = ProfileReport(df2, title="Pandas Profiling Report")
profile_posle_2.to_file('инфо_3.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df2['категория дохода'] = pd.qcut(df2['ежемесячный доход'], q = [0, 0.25, 0.5, 0.75, 1], labels=['маленький','умеренный','средний', 'большой'])

# %% [markdown]
# Исследовательский анализ данных и проверка гипотез

# %% [markdown]
# Для проверки последней гипотезы, посмотрим наш файлик инфо3.html, проведем категоризацию наших ежемесячных доходов, по квантилям.

# %%
df2['категория дохода'] = pd.qcut(df2['ежемесячный доход'], q = [0, 0.25, 0.5, 0.75, 1], labels=['маленький','умеренный','средний', 'большой'])

# %%
pd.qcut(df2['ежемесячный доход'], q = [0, 0.25, 0.5, 0.75, 1])
# Out:
# 0          (20667.263, 105685.075]
# 1          (20667.263, 105685.075]
# 2          (20667.263, 105685.075]
# 3          (20667.263, 105685.075]
# 4        (201931.576, 2265604.029]
#                    ...
# 21078    (201931.576, 2265604.029]
# 21079     (146514.255, 201931.576]
# 21080      (20667.263, 105685.075]
# 21081    (201931.576, 2265604.029]
# 21082      (20667.263, 105685.075]
# Name: ежемесячный доход, Length: 21083, dtype: category
# Categories (4, interval[float64, right]): [(20667.263, 105685.075] < (105685.075, 146514.255] < (146514.255, 201931.576] < (201931.576, 2265604.029]]

# %%
col = ['количество детей в семье', 'идентификатор семейного положения', 'категория кредита', 'категория дохода']

# %%
for i in col:
    print('\n')
    print('признак : ',i)
    r = df2[[i,'имел ли задолженность по возврату кредитов']].groupby(i)
    try :
        for j in r.groups:
            print('группа : ',j)
            dolg_no = r.get_group(j)['имел ли задолженность по возврату кредитов'].value_counts()[0]
            dolg_yes = r.get_group(j)['имел ли задолженность по возврату кредитов'].value_counts()[1]
            print(f'задолженности не было у {dolg_no} человек')
            print(f'задолженность была у {dolg_yes} человек')
            print(round(dolg_yes/dolg_no*100),' % от тех, кто не имел задолженность')
            print('\n')
    except: 
        print(f'задолженности не было у {dolg_no} человек')
        print('отсутствует долг')
# Out:
# признак :  количество детей в семье
# группа :  0.0
# задолженности не было у 12828 человек
# задолженность была у 1062 человек
# 8  % от тех, кто не имел задолженность
#
#
# группа :  1.0
# задолженности не было у 4330 человек
# задолженность была у 443 человек
# 10  % от тех, кто не имел задолженность
#
#
# группа :  2.0
# задолженности не было у 1848 человек
# задолженность была у 193 человек
# 10  % от тех, кто не имел задолженность
#
#
# группа :  3.0
# задолженности не было у 302 человек
# задолженность была у 27 человек
# 9  % от тех, кто не имел задолженность
#
#
# группа :  4.0
# задолженности не было у 37 человек
# задолженность была у 4 человек
# 11  % от тех, кто не имел задолженность
#
#
# группа :  5.0
# задолженности не было у 9 человек
# отсутствует долг
#
#
# признак :  идентификатор семейного положения
# группа :  Не женат / не замужем
# задолженности не было у 2505 человек
# задолженность была у 273 человек
# 11  % от тех, кто не имел задолженность
#
#
# группа :  в разводе
# задолженности не было у 1103 человек
# задолженность была у 84 человек
# 8  % от тех, кто не имел задолженность
#
#
# группа :  вдовец / вдова
# задолженности не было у 876 человек
# задолженность была у 63 человек
# 7  % от тех, кто не имел задолженность
#
#
# группа :  гражданский брак
# задолженности не было у 3714 человек
# задолженность была у 385 человек
# 10  % от тех, кто не имел задолженность
#
#
# группа :  женат / замужем
# задолженности не было у 11156 человек
# задолженность была у 924 человек
# 8  % от тех, кто не имел задолженность
#
#
#
#
# признак :  категория кредита
# группа :  автокредитование
# задолженности не было у 3846 человек
# задолженность была у 398 человек
# 10  % от тех, кто не имел задолженность
#
#
# группа :  жилищное кредитование
# задолженности не было у 6353 человек
# задолженность была у 503 человек
# 8  % от тех, кто не имел задолженность
#
#
# группа :  образовательный кредит
# задолженности не было у 3570 человек
# задолженность была у 369 человек
# 10  % от тех, кто не имел задолженность
#
#
# группа :  потребительский кредит
# задолженности не было у 4380 человек
# задолженность была у 361 человек
# 8  % от тех, кто не имел задолженность
#
#
# группа :  развитие бизнеса
# задолженности не было у 1205 человек
# задолженность была у 98 человек
# 8  % от тех, кто не имел задолженность
#
#
#
#
# признак :  категория дохода
# группа :  маленький
# задолженности не было у 4856 человек
# задолженность была у 415 человек
# 9  % от тех, кто не имел задолженность
#
#
# группа :  умеренный
# задолженности не было у 4798 человек
# задолженность была у 473 человек
# 10  % от тех, кто не имел задолженность
#
#
# группа :  средний
# задолженности не было у 4796 человек
# задолженность была у 474 человек
# 10  % от тех, кто не имел задолженность
#
#
# группа :  большой
# задолженности не было у 4904 человек
# задолженность была у 367 человек
# 7  % от тех, кто не имел задолженность

# %% [markdown]
# Выводы по вышеизложенной информации:
#   - Зависимость наличия детей и возвратом кредита, не значительна. Самый меньший процент, от числа, у кого нет задолженности -8%.
#   - Зависисмость от семейного положения присутствует, но слабая. Самый меньший процент у категории "вдова/вдовец" 7%, что не скажешь, о людях категории - не женат/не замужем.
#   - Зависимость  между уровнем дохода и вовзратом кредита, также есть, но не такая явная.
#   Низкий процент у людей, у кого большой доход, у людей категории маленький доход - 9%, не так далеко отстают.
#   - Автокредитование, и Кредит образования больше влияют на вовзрат в срок, остальные держутся на 8%. Жилищное кредитование, и потребительский кредит, даже при таком количестве людей, держится на 8%.
